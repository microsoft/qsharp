# %%
import qsharp
qsharp.init(project_root='.')
# Out:
# Q# initialized with configuration: {'targetProfile': 'unrestricted', 'languageFeatures': None, 'manifest': '{\n    "dependencies": {\n        "Foo": {\n            "path": "../DependencyA"\n        },\n        "GitHub": {\n            "github": {\n                "owner": "sezna",\n                "repo": "qsharp-project-template",\n                "ref": "main"\n            }\n        }\n    }\n}\n'}

# %%
# %%qsharp
#
# // language service errors are ok, we never got that working.
# // should work at runtime though.
# MyQuantumApp.Main();
# Foo.DependencyA.IntAsBigInt(5);
#
# GitHub.Diagnostics.Fact_(true, "yes");
# Out:
# Qsc.Resolve.NotFound
#
#   × name error
#   ╰─▶ `Foo.DependencyA.IntAsBigInt` not found
#    ╭─[line_0:4:1]
#  4 │ MyQuantumApp.Main();
#  5 │ Foo.DependencyA.IntAsBigInt(5);
#    · ───────────────────────────
#  6 │
#    ╰────
# Qsc.Resolve.NotFound
#
#   × name error
#   ╰─▶ `GitHub.Diagnostics.Fact_` not found
#    ╭─[line_0:6:1]
#  6 │
#  7 │ GitHub.Diagnostics.Fact_(true, "yes");
#    · ────────────────────────
#    ╰────
# Qsc.TypeCk.AmbiguousTy
#
#   × type error
#   ╰─▶ insufficient type information to infer type
#    ╭─[line_0:4:1]
#  4 │ MyQuantumApp.Main();
#  5 │ Foo.DependencyA.IntAsBigInt(5);
#    · ──────────────────────────────
#  6 │
#    ╰────
#   help: provide a type annotation
# Qsc.TypeCk.AmbiguousTy
#
#   × type error
#   ╰─▶ insufficient type information to infer type
#    ╭─[line_0:6:1]
#  6 │
#  7 │ GitHub.Diagnostics.Fact_(true, "yes");
#    · ─────────────────────────────────────
#    ╰────
#   help: provide a type annotation
